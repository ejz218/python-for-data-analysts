# %% [markdown]
# # BUAN 446 Week 4 Assignment
# ## NumPy and Pandas Fundamentals
#
# ---
#
# **Name:** _____________________
#
# **Date:** _____________________
#
# ---
#
# ### Instructions
#
# This assignment reinforces the NumPy and pandas skills covered in Chapters 6 and 7. You will practice array operations, DataFrame manipulation, and basic data analysis.
#
# **Rules:**
# - You **MAY** use AI tools to help with this assignment
# - You **MUST** understand and be able to explain all code you submit
# - Document any AI usage in the reflection section at the end
#
# **Grading:**
# - Part 1: NumPy Array Operations (25 points)
# - Part 2: NumPy Statistical Analysis (25 points)
# - Part 3: Pandas DataFrame Basics (25 points)
# - Part 4: Pandas GroupBy Analysis (25 points)
# - **Total: 100 points**
#
# ---

# %% [markdown]
# # Part 1: NumPy Array Operations (25 points)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Task 1.1: Array Creation (5 points)
#
# Create the following arrays:
# 1. An array called `gpa_scale` containing values [0.0, 1.0, 2.0, 3.0, 4.0]
# 2. An array called `zeros_3x4` that is a 3-row by 4-column array of zeros
# 3. An array called `credit_range` with 10 evenly spaced values from 0 to 120
#
# Print each array with a label.

# %%
# Your code here

# %% [markdown]
# ### Task 1.2: Array Indexing and Slicing (10 points)
#
# Given the following array of GPAs:

# %%
gpas = np.array([3.2, 3.8, 2.5, 3.9, 2.1, 3.5, 4.0, 2.8, 3.1, 3.7])

# %% [markdown]
# Write code to extract and print:
# 1. The first three GPAs
# 2. The last two GPAs
# 3. Every other GPA (indices 0, 2, 4, ...)
# 4. The GPAs in reverse order
# 5. The GPAs at indices 2, 5, and 8 (use fancy indexing with a list)

# %%
# Your code here
print("1. First three GPAs:")


print("\n2. Last two GPAs:")


print("\n3. Every other GPA:")


print("\n4. Reversed GPAs:")


print("\n5. GPAs at indices 2, 5, 8:")

# %% [markdown]
# ### Task 1.3: Vectorized Operations (10 points)
#
# Given these arrays:

# %%
credits_attempted = np.array([105, 87, 92, 110, 45, 68, 120, 55, 78, 95])
credits_earned = np.array([100, 80, 88, 105, 40, 62, 115, 50, 72, 90])

# %% [markdown]
# Without using any loops, calculate:
# 1. `completion_rate`: The completion rate for each student (earned / attempted * 100)
# 2. `credits_failed`: The number of credits not earned for each student
# 3. `adjusted_gpa`: The GPAs from the earlier array, each increased by 0.1 (cap at 4.0 using `np.minimum`)
#
# Print each result with appropriate labels.

# %%
# Your code here

# %% [markdown]
# ---
#
# # Part 2: NumPy Statistical Analysis (25 points)

# %% [markdown]
# ### Task 2.1: Basic Statistics (10 points)
#
# Using the `gpas` array from Part 1, calculate and print:
# 1. Mean GPA
# 2. Median GPA
# 3. Standard deviation
# 4. Minimum and maximum values
# 5. The range (max - min)
#
# Format all outputs to 2 decimal places.

# %%
# Your code here

# %% [markdown]
# ### Task 2.2: Boolean Indexing (15 points)
#
# Using the `gpas` array, write code to:
#
# 1. Find all GPAs that qualify for Dean's List (>= 3.5)
# 2. Count how many students are on academic probation (< 2.0)
# 3. Find GPAs that are between 2.5 and 3.5 (inclusive)
# 4. Calculate the mean GPA of only the Dean's List students
# 5. Replace all GPAs below 2.0 with 2.0 (in a copy of the array) and print the modified array

# %%
# Your code here
print("1. Dean's List GPAs (>= 3.5):")


print("\n2. Students on probation (< 2.0):")


print("\n3. GPAs between 2.5 and 3.5:")


print("\n4. Mean GPA of Dean's List students:")


print("\n5. Array with probation GPAs raised to 2.0:")

# %% [markdown]
# ---
#
# # Part 3: Pandas DataFrame Basics (25 points)

# %% [markdown]
# ### Task 3.1: Loading and Inspecting Data (10 points)
#
# 1. Load `lehigh_students_clean.csv` into a DataFrame called `df`
# 2. Display the shape of the DataFrame
# 3. Display the column names and their data types
# 4. Show the first 5 and last 5 rows
# 5. Display summary statistics using `describe()`

# %%
# Your code here

# %% [markdown]
# ### Task 3.2: Column Selection and Filtering (15 points)
#
# Write code to:
#
# 1. Select just the Student_ID and GPA columns and display the first 10 rows
# 2. Filter for students with GPA >= 3.5 and count how many there are
# 3. Filter for students in "College of Business" with GPA < 3.0
# 4. Find all unique values in the Class_Year column
# 5. Create a new column called `Completion_Rate` = Credits_Earned / Credits_Attempted * 100

# %%
# 1. Select Student_ID and GPA columns
print("1. Student_ID and GPA (first 10 rows):")

# %%
# 2. Students with GPA >= 3.5
print("2. Number of students with GPA >= 3.5:")

# %%
# 3. Business students with GPA < 3.0
print("3. Business students with GPA < 3.0:")

# %%
# 4. Unique Class_Year values
print("4. Unique Class Years:")

# %%
# 5. Create Completion_Rate column
print("5. DataFrame with Completion_Rate column (first 5 rows):")

# %% [markdown]
# ---
#
# # Part 4: Pandas GroupBy Analysis (25 points)

# %% [markdown]
# ### Task 4.1: Basic GroupBy (10 points)
#
# Using the DataFrame from Part 3:
#
# 1. Calculate the mean GPA for each College
# 2. Count the number of students in each Class_Year
# 3. Find the maximum GPA in each College

# %%
# 1. Mean GPA by College
print("1. Mean GPA by College:")

# %%
# 2. Student count by Class_Year
print("2. Student count by Class Year:")

# %%
# 3. Maximum GPA by College
print("3. Maximum GPA by College:")

# %% [markdown]
# ### Task 4.2: Advanced GroupBy (15 points)
#
# 1. Create a summary table showing mean GPA and mean Completion_Rate for each College, sorted by mean GPA (highest first)
#
# 2. For each Class_Year, calculate:
#    - Number of students
#    - Mean GPA
#    - Min GPA
#    - Max GPA
#
# 3. Find the top 5 majors by number of students and show their average GPA

# %%
# 1. Summary table by College
print("1. College Summary (sorted by GPA):")

# %%
# 2. Class_Year statistics
print("2. Class Year Statistics:")

# %%
# 3. Top 5 majors by enrollment with average GPA
print("3. Top 5 Majors by Enrollment:")

# %% [markdown]
# ---
#
# # Reflection
#
# Answer the following questions:
#
# **1. Which task was most challenging and why?**
#
# *Your answer:*
#
# **2. What's the difference between using a loop and NumPy's vectorized operations? When would you use each?**
#
# *Your answer:*
#
# **3. Did you use AI assistance? If so, for which parts? What did you learn from the AI's responses?**
#
# *Your answer:*
#
# ---
#
# ## Submission
#
# Save your completed notebook and submit the .ipynb file via CourseConnect.
