# %% [markdown]
# # BUAN 446 Week 5 Assignment
# ## Data Visualization with Matplotlib and Seaborn
#
# ---
#
# **Name:** _____________________
#
# **Date:** _____________________
#
# ---
#
# ### Instructions
#
# This assignment reinforces the data visualization skills covered in Chapter 8. You will create various chart types, customize their appearance, and practice choosing appropriate visualizations for different questions — all using the **extended Crestview student dataset** (600 students, 15 variables).
#
# **Rules:**
# - You **MAY** use AI tools to help with this assignment
# - You **MUST** understand and be able to explain all code you submit
# - All visualizations must be publication-quality (proper titles, labels, legends)
# - Document any AI usage in the reflection section at the end
#
# **Grading:**
# - Part 1: Basic Matplotlib Charts (25 points)
# - Part 2: Customization and Styling (25 points)
# - Part 3: Seaborn Statistical Plots (25 points)
# - Part 4: Multi-Panel Figures (25 points)
# - **Total: 100 points**
#
# ---

# %% [markdown]
# ## Setup
#
# Run the cell below to import libraries and load the data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the extended student data
df = pd.read_csv('../data/crestview_students_extended.csv')

# Create derived columns
df['Completion_Rate'] = (df['Credits_Earned'] / df['Credits_Attempted'] * 100).round(1)
df['Study_Efficiency'] = (df['GPA'] / df['Study_Hours_Per_Week']).round(3)
df['Has_Job'] = df['Part_Time_Job'] != 'No'

def classify_standing(gpa):
    if gpa >= 3.5:
        return "Dean's List"
    elif gpa >= 2.0:
        return "Good Standing"
    else:
        return "Probation"

df['Academic_Standing'] = df['GPA'].apply(classify_standing)

# Set default figure size
plt.rcParams['figure.figsize'] = [10, 6]
plt.rcParams['figure.dpi'] = 100

print(f"Loaded {len(df)} student records with {len(df.columns)} variables")
print(f"Columns: {df.columns.tolist()}")
df.head()
# Out:
# Loaded 600 student records with 19 variables
# Columns: ['Student_ID', 'College', 'Major', 'Class_Year', 'GPA', 'Credits_Attempted', 'Credits_Earned', 'Enrollment_Date', 'Study_Hours_Per_Week', 'Campus_Housing', 'Financial_Aid', 'Extracurriculars', 'Part_Time_Job', 'First_Generation', 'Distance_From_Home', 'Completion_Rate', 'Study_Efficiency', 'Has_Job', 'Academic_Standing']
#   Student_ID                 College                   Major Class_Year   GPA  \
# 0   CU100001     College of Business              Accounting     Senior  3.41
# 1   CU100002    College of Education    Elementary Education     Junior  3.55
# 2   CU100003  College of Engineering  Electrical Engineering     Junior  3.60
# 3   CU100004       College of Health                 Nursing     Senior  3.44
# 4   CU100005  College of Engineering    Computer Engineering  Sophomore  3.90
#
#    Credits_Attempted  Credits_Earned Enrollment_Date  Study_Hours_Per_Week  \
# 0                105              99      2021-01-24                  14.2
# 1                 73              62      2022-09-07                  19.9
# 2                 89              81      2022-08-09                  24.8
# 3                102              98      2021-08-03                  29.6
# 4                 52              44      2023-01-28                  15.3
#
#   Campus_Housing Financial_Aid  Extracurriculars Part_Time_Job  \
# 0     Off-campus            No                 3     Yes (18h)
# 1     Off-campus            No                 2            No
# 2      On-campus           Yes                 0            No
# 3     Off-campus            No                 2            No
# 4      On-campus           Yes                 1     Yes (11h)
#
#   First_Generation  Distance_From_Home  Completion_Rate  Study_Efficiency  \
# 0              NaN                  19             94.3             0.240
# 1               No                 363             84.9             0.178
# 2               No                 749             91.0             0.145
# 3               No                  19             96.1             0.116
# 4               No                  68             84.6             0.255
#
#    Has_Job Academic_Standing
# 0     True     Good Standing
# 1    False       Dean's List
# 2    False       Dean's List
# 3    False     Good Standing
# 4     True       Dean's List

# %% [markdown]
# ---
#
# # Part 1: Basic Matplotlib Charts (25 points)

# %% [markdown]
# ### Task 1.1: Histogram (8 points)
#
# Create a histogram of student GPAs with the following requirements:
# - Use 25 bins
# - Add black edges to the bars
# - Set transparency (alpha) to 0.7
# - Add a title: "Distribution of Student GPAs at Crestview University"
# - Label the x-axis: "GPA"
# - Label the y-axis: "Number of Students"
# - Add a vertical dashed red line at the mean GPA with a label
# - Add a vertical dashed green line at GPA = 3.5 (Dean's List threshold)
# - Include a legend

# %%
# Your code here





plt.show()

# %% [markdown]
# ### Task 1.2: Bar Chart (8 points)
#
# Create a bar chart showing the number of students in each college:
# - Calculate the count of students per college
# - Sort the bars from most students to fewest
# - Add a title: "Student Enrollment by College"
# - Label the axes appropriately
# - Rotate x-axis labels 45 degrees for readability
# - Use `plt.tight_layout()` to prevent label cutoff

# %%
# Your code here





plt.show()

# %% [markdown]
# ### Task 1.3: Scatter Plot (9 points)
#
# Create a scatter plot showing Study_Hours_Per_Week vs GPA:
# - Use alpha=0.5 for transparency (since points may overlap)
# - Add a horizontal dashed red line at GPA = 3.5 (Dean's List threshold)
# - Add a title: "Study Hours vs GPA at Crestview University"
# - Label the axes appropriately
# - Add a legend for the reference line
# - Make the figure size (10, 6)

# %%
# Your code here





plt.show()

# %% [markdown]
# ---
#
# # Part 2: Customization and Styling (25 points)

# %% [markdown]
# ### Task 2.1: Horizontal Bar Chart with Values (10 points)
#
# Create a horizontal bar chart showing average GPA by college:
# - Calculate mean GPA for each college
# - Sort from highest to lowest GPA
# - Use `plt.barh()` for horizontal bars
# - Add the GPA value as text at the end of each bar (hint: use `plt.text()` or `ax.text()`)
# - Use a color gradient or distinct colors for each bar
# - Add title and axis labels

# %%
# Your code here





plt.show()

# %% [markdown]
# ### Task 2.2: Styled Pie Chart (7 points)
#
# Create a pie chart showing the distribution of Academic Standing:
# - Count students in each Academic Standing category
# - Use appropriate colors (green for Dean's List, blue for Good Standing, red for Probation)
# - Show percentages on each slice
# - "Explode" the Probation slice slightly to highlight it
# - Add a title: "Academic Standing Distribution"

# %%
# Your code here





plt.show()

# %% [markdown]
# ### Task 2.3: Saving Figures (8 points)
#
# Recreate the histogram from Task 1.1 and save it in two formats:
# 1. Save as 'gpa_distribution.png' with dpi=150
# 2. Save as 'gpa_distribution.pdf' for vector graphics
#
# Use `bbox_inches='tight'` to prevent cutoff.
#
# Print a confirmation message after each save.

# %%
# Your code here





plt.show()

# %% [markdown]
# ---
#
# # Part 3: Seaborn Statistical Plots (25 points)

# %% [markdown]
# ### Task 3.1: Box Plot (8 points)
#
# Create a seaborn box plot showing GPA distribution by Campus_Housing type:
# - Add horizontal reference lines at GPA = 2.0 (red) and GPA = 3.5 (green)
# - Add a title: "GPA Distribution by Campus Housing"
# - Label axes appropriately

# %%
# Your code here





plt.show()

# %% [markdown]
# ### Task 3.2: Scatter Plot with Hue (8 points)
#
# Create a seaborn scatter plot:
# - x-axis: Study_Hours_Per_Week
# - y-axis: GPA
# - Color points by Campus_Housing using the `hue` parameter
# - Use alpha=0.6 for transparency
# - Add title: "Study Hours vs GPA by Campus Housing"
# - Move the legend outside the plot if it overlaps with data

# %%
# Your code here





plt.show()

# %% [markdown]
# ### Task 3.3: Violin Plot (9 points)
#
# Create a seaborn violin plot comparing GPA across Financial_Aid status:
# - x-axis: Financial_Aid
# - y-axis: GPA
# - Add a title: "GPA Distribution by Financial Aid Status"
# - Add axis labels
#
# **Interpretation:** Write 2-3 sentences below the plot explaining what the visualization reveals about the relationship between financial aid and academic performance.

# %%
# Your code here





plt.show()

# %% [markdown]
# **Your interpretation:**
#
# *Write 2-3 sentences here*

# %% [markdown]
# ---
#
# # Part 4: Multi-Panel Figures (25 points)

# %% [markdown]
# ### Task 4.1: Side-by-Side Comparison (10 points)
#
# Create a figure with 1 row and 2 columns comparing:
# - Left: Histogram of Study_Hours_Per_Week
# - Right: Histogram of GPA
#
# Requirements:
# - Use `fig, axes = plt.subplots(1, 2, figsize=(14, 5))`
# - Each subplot should have its own title
# - Add appropriate axis labels to each
# - Use `plt.tight_layout()`

# %%
# Your code here





plt.show()

# %% [markdown]
# ### Task 4.2: Comprehensive Dashboard (15 points)
#
# Create a 2x2 dashboard figure with the following plots:
#
# 1. **Top-left:** Box plot of GPA by Campus_Housing (use seaborn)
# 2. **Top-right:** Bar chart of student count by Class Year (in logical order)
# 3. **Bottom-left:** Scatter plot of Study_Hours_Per_Week vs GPA with color by Financial_Aid
# 4. **Bottom-right:** Box plot of Study_Hours_Per_Week by Academic_Standing
#
# Requirements:
# - Use `figsize=(16, 12)`
# - Each subplot must have a descriptive title
# - Rotate x-axis labels where needed
# - Use `plt.tight_layout()`
# - Add a main title for the entire figure using `plt.suptitle()`
# - Save the dashboard as 'student_dashboard.png' with dpi=150

# %%
# Your code here








plt.show()

# %% [markdown]
# ---
#
# # Bonus Challenge (Optional, +5 points)
#
# Create a heatmap showing the correlation between all numerical variables (GPA, Credits_Attempted, Credits_Earned, Completion_Rate, Study_Hours_Per_Week, Extracurriculars, Distance_From_Home):
# - Calculate the correlation matrix using `df[columns].corr()`
# - Use `sns.heatmap()` with annotations showing the correlation values
# - Use an appropriate colormap (e.g., 'coolwarm' or 'RdYlGn')
# - Add a title
#
# **Interpretation:** Which variables are most strongly correlated? Which relationships are surprising? Does Study_Hours_Per_Week correlate with GPA as strongly as you'd expect?

# %%
# Bonus code here (optional)

# %% [markdown]
# **Bonus interpretation:**
#
# *Your answer here (optional)*

# %% [markdown]
# ---
#
# # Reflection
#
# Answer the following questions:
#
# **1. When would you choose matplotlib over seaborn, and vice versa?**
#
# *Your answer:*
#
# **2. What makes a visualization "publication-quality"? What elements did you include to achieve this?**
#
# *Your answer:*
#
# **3. Which visualization from this assignment do you think communicates its message most effectively? Why?**
#
# *Your answer:*
#
# **4. Did you use AI assistance? If so, for which parts? What did you learn?**
#
# *Your answer:*
#
# ---
#
# ## Submission
#
# Submit the following files via CourseConnect:
# 1. This completed notebook (.ipynb)
# 2. gpa_distribution.png
# 3. gpa_distribution.pdf
# 4. student_dashboard.png
